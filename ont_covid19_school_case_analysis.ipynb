# %% [markdown]
# # ONTARIO SCHOOLS WITH COVID-19 CASES ANALYSIS
# ## Initial Cleaning of Data set for further analysis
#
# ### Peter Stangolis
#
# #### [Data URL:](https://data.ontario.ca/dataset/b1fef838-8784-4338-8ef9-ae7cfd405b41/resource/7fbdbb48-d074-45d9-93cb-f7de58950418/download/schoolcovidsummary.csv)

# %% [markdown]
# ### Import the required libraries for the analysis

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from matplotlib.pyplot import figure

from pylab import rcParams
#rcParams['figure.figsize'] = 18, 6

import datetime
import seaborn as sns

# %%
# Graph Style Settings:

plt.figure(figsize=(7, 4))

plt.style.use(['default', 'tableau-colorblind10'])

# %matplotlib inline

# %%
for s in plt.style.available:
    print(s)
# Out:
# Solarize_Light2
# _classic_test_patch
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn
# seaborn-bright
# seaborn-colorblind
# seaborn-dark
# seaborn-dark-palette
# seaborn-darkgrid
# seaborn-deep
# seaborn-muted
# seaborn-notebook
# seaborn-paper
# seaborn-pastel
# seaborn-poster
# seaborn-talk
# seaborn-ticks
# seaborn-white
# seaborn-whitegrid
# tableau-colorblind10

# %% [markdown]
# ### Import the data set into a dataframe

# %%
url = 'https://data.ontario.ca/dataset/b1fef838-8784-4338-8ef9-ae7cfd405b41/resource/7fbdbb48-d074-45d9-93cb-f7de58950418/download/schoolcovidsummary.csv'

df = pd.read_csv(url)

# View the last 5 rows of the data set
df.tail()
# Out:
#    collected_date reported_date  current_schools_w_cases  \
# 48     2020-11-18    2020-11-19                      680
# 49     2020-11-19    2020-11-20                      681
# 50     2020-11-20    2020-11-23                      676
# 51     2020-11-23    2020-11-24                      703
# 52     2020-11-24    2020-11-25                      688
#
#     current_schools_closed  current_total_number_schools  \
# 48                       3                          4828
# 49                       3                          4828
# 50                       3                          4828
# 51                       4                          4828
# 52                       4                          4828
#
#     new_total_school_related_cases  new_school_related_student_cases  \
# 48                              91                                75
# 49                              87                                60
# 50                              60                                51
# 51                             270                               223
# 52                             162                               138
#
#     new_school_related_staff_cases  new_school_related_unspecified_cases  \
# 48                              16                                   0.0
# 49                              27                                   0.0
# 50                               9                                   0.0
# 51                              47                                   0.0
# 52                              24                                   0.0
#
#     recent_total_school_related_cases  ...  \
# 48                             1143.0  ...
# 49                             1150.0  ...
# 50                             1133.0  ...
# 51                             1281.0  ...
# 52                             1193.0  ...
#
#     recent_school_related_unspecified_cases  past_total_school_related_cases  \
# 48                                    299.0                           2567.0
# 49                                    271.0                           2653.0
# 50                                    244.0                           2737.0
# 51                                    211.0                           2889.0
# 52                                    150.0                           3076.0
#
#     past_school_related_student_cases  past_school_related_staff_cases  \
# 48                             1451.0                            328.0
# 49                             1503.0                            334.0
# 50                             1549.0                            345.0
# 51                             1648.0                            366.0
# 52                             1752.0                            387.0
#
#     past_school_related_unspecified_cases  cumulative_school_related_cases  \
# 48                                  788.0                             3710
# 49                                  816.0                             3803
# 50                                  843.0                             3870
# 51                                  875.0                             4170
# 52                                  937.0                             4269
#
#     cumulative_school_related_student_cases  \
# 48                                     2147
# 49                                     2209
# 50                                     2267
# 51                                     2516
# 52                                     2609
#
#     cumulative_school_related_staff_cases  \
# 48                                    476
# 49                                    507
# 50                                    516
# 51                                    568
# 52                                    573
#
#     cumulative_school_related_unspecified_cases  Unnamed: 21
# 48                                       1087.0          NaN
# 49                                       1087.0          NaN
# 50                                       1087.0          NaN
# 51                                       1086.0          NaN
# 52                                       1087.0          NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Initial Exploratory Data Analysis of the data set

# %%
# retrieve information concerning the data in columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 22 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   collected_date                               53 non-null     object
#  1   reported_date                                53 non-null     object
#  2   current_schools_w_cases                      53 non-null     int64
#  3   current_schools_closed                       53 non-null     int64
#  4   current_total_number_schools                 53 non-null     int64
#  5   new_total_school_related_cases               53 non-null     int64
#  6   new_school_related_student_cases             53 non-null     int64
#  7   new_school_related_staff_cases               53 non-null     int64
#  8   new_school_related_unspecified_cases         51 non-null     float64
#  9   recent_total_school_related_cases            39 non-null     float64
#  10  recent_school_related_student_cases          39 non-null     float64
#  11  recent_school_related_staff_cases            39 non-null     float64
#  12  recent_school_related_unspecified_cases      39 non-null     float64
#  13  past_total_school_related_cases              39 non-null     float64
#  14  past_school_related_student_cases            39 non-null     float64
#  15  past_school_related_staff_cases              39 non-null     float64
#  16  past_school_related_unspecified_cases        39 non-null     float64
#  17  cumulative_school_related_cases              53 non-null     int64
#  18  cumulative_school_related_student_cases      53 non-null     int64
#  19  cumulative_school_related_staff_cases        53 non-null     int64
#  20  cumulative_school_related_unspecified_cases  51 non-null     float64
#  21  Unnamed: 21                                  0 non-null      float64
# dtypes: float64(11), int64(9), object(2)
# memory usage: 9.2+ KB

# %% [markdown]
# ### Change the datatype of the 'reported_date' column to datetime from object

# %%
df['reported_date'] = pd.to_datetime(df['reported_date'])

# %%
df['reported_date'].head()
# Out:
# 0   2020-09-11
# 1   2020-09-14
# 2   2020-09-15
# 3   2020-09-16
# 4   2020-09-17
# Name: reported_date, dtype: datetime64[ns]

# %%
df.describe()
# Out:
#        current_schools_w_cases  current_schools_closed  \
# count                53.000000               53.000000
# mean                431.339623                2.056604
# std                 217.615835                1.549381
# min                  13.000000                0.000000
# 25%                 282.000000                1.000000
# 50%                 501.000000                2.000000
# 75%                 593.000000                3.000000
# max                 703.000000                5.000000
#
#        current_total_number_schools  new_total_school_related_cases  \
# count                          53.0                       53.000000
# mean                         4828.0                       82.113208
# std                             0.0                       50.950074
# min                          4828.0                        0.000000
# 25%                          4828.0                       52.000000
# 50%                          4828.0                       74.000000
# 75%                          4828.0                      109.000000
# max                          4828.0                      270.000000
#
#        new_school_related_student_cases  new_school_related_staff_cases  \
# count                         53.000000                       53.000000
# mean                          50.207547                       11.132075
# std                           37.809929                        8.318279
# min                            0.000000                        0.000000
# 25%                           29.000000                        5.000000
# 50%                           48.000000                        9.000000
# 75%                           63.000000                       14.000000
# max                          223.000000                       47.000000
#
#        new_school_related_unspecified_cases  \
# count                             51.000000
# mean                              21.588235
# std                               15.725364
# min                                0.000000
# 25%                                7.500000
# 50%                               21.000000
# 75%                               30.000000
# max                               65.000000
#
#        recent_total_school_related_cases  recent_school_related_student_cases  \
# count                          39.000000                            39.000000
# mean                          860.769231                           502.128205
# std                           230.952087                           154.406194
# min                           386.000000                           212.000000
# 25%                           710.500000                           407.500000
# 50%                           897.000000                           493.000000
# 75%                          1039.500000                           617.500000
# max                          1281.000000                           868.000000
#
#        recent_school_related_staff_cases  \
# count                          39.000000
# mean                          106.076923
# std                            33.149093
# min                            59.000000
# 25%                            86.500000
# 50%                           100.000000
# 75%                           115.000000
# max                           202.000000
#
#        recent_school_related_unspecified_cases  \
# count                                39.000000
# mean                                252.512821
# std                                  76.945255
# min                                 114.000000
# 25%                                 181.000000
# 50%                                 271.000000
# 75%                                 317.000000
# max                                 354.000000
#
#        past_total_school_related_cases  past_school_related_student_cases  \
# count                        39.000000                          39.000000
# mean                       1296.487179                         723.948718
# std                         921.842944                         526.802417
# min                          61.000000                          21.000000
# 25%                         483.000000                         255.000000
# 50%                        1175.000000                         664.000000
# 75%                        2075.000000                        1151.000000
# max                        3076.000000                        1752.000000
#
#        past_school_related_staff_cases  past_school_related_unspecified_cases  \
# count                        39.000000                              39.000000
# mean                        186.025641                             386.487179
# std                         111.532032                             284.515643
# min                          23.000000                              17.000000
# 25%                          87.000000                             141.000000
# 50%                         183.000000                             328.000000
# 75%                         283.000000                             641.000000
# max                         387.000000                             937.000000
#
#        cumulative_school_related_cases  \
# count                        53.000000
# mean                       1625.339623
# std                        1326.861826
# min                          13.000000
# 25%                         342.000000
# 50%                        1429.000000
# 75%                        2628.000000
# max                        4269.000000
#
#        cumulative_school_related_student_cases  \
# count                                53.000000
# mean                                920.094340
# std                                 775.400672
# min                                   4.000000
# 25%                                 188.000000
# 50%                                 810.000000
# 75%                                1484.000000
# max                                2609.000000
#
#        cumulative_school_related_staff_cases  \
# count                              53.000000
# mean                              222.981132
# std                               165.428289
# min                                 9.000000
# 25%                                52.000000
# 50%                               223.000000
# 75%                               328.000000
# max                               573.000000
#
#        cumulative_school_related_unspecified_cases  Unnamed: 21
# count                                    51.000000          0.0
# mean                                    501.196078          NaN
# std                                     384.659383          NaN
# min                                       6.000000          NaN
# 25%                                     134.500000          NaN
# 50%                                     460.000000          NaN
# 75%                                     829.500000          NaN
# max                                    1088.000000          NaN

# %% [markdown]
# ### Missing Value Analysis

# %%
df.isnull().sum()
# Out:
# collected_date                                  0
# reported_date                                   0
# current_schools_w_cases                         0
# current_schools_closed                          0
# current_total_number_schools                    0
# new_total_school_related_cases                  0
# new_school_related_student_cases                0
# new_school_related_staff_cases                  0
# new_school_related_unspecified_cases            2
# recent_total_school_related_cases              14
# recent_school_related_student_cases            14
# recent_school_related_staff_cases              14
# recent_school_related_unspecified_cases        14
# past_total_school_related_cases                14
# past_school_related_student_cases              14
# past_school_related_staff_cases                14
# past_school_related_unspecified_cases          14
# cumulative_school_related_cases                 0
# cumulative_school_related_student_cases         0
# cumulative_school_related_staff_cases           0
# cumulative_school_related_unspecified_cases     2
# Unnamed: 21                                    53
# dtype: int64

# %% [markdown]
# ### Drop the columns not required for the analysis
#
#
# * collected_date
# * recent_total_school_related_cases
# * recent_school_related_student_cases
# * recent_school_related_staff_cases
# * recent_school_related_unspecified_cases
# * past_total_school_related_cases
# * past_school_related_student_cases
# * past_school_related_staff_cases
# * past_school_related_unspecified_cases
# * Unnamed: 21

# %%
df = df.iloc[:,  [1,2,3,4,5,6,7,8,9, 17, 18, 19, 20]]

# %%
df.tail()
# Out:
#    reported_date  current_schools_w_cases  current_schools_closed  \
# 48    2020-11-19                      680                       3
# 49    2020-11-20                      681                       3
# 50    2020-11-23                      676                       3
# 51    2020-11-24                      703                       4
# 52    2020-11-25                      688                       4
#
#     current_total_number_schools  new_total_school_related_cases  \
# 48                          4828                              91
# 49                          4828                              87
# 50                          4828                              60
# 51                          4828                             270
# 52                          4828                             162
#
#     new_school_related_student_cases  new_school_related_staff_cases  \
# 48                                75                              16
# 49                                60                              27
# 50                                51                               9
# 51                               223                              47
# 52                               138                              24
#
#     new_school_related_unspecified_cases  recent_total_school_related_cases  \
# 48                                   0.0                             1143.0
# 49                                   0.0                             1150.0
# 50                                   0.0                             1133.0
# 51                                   0.0                             1281.0
# 52                                   0.0                             1193.0
#
#     cumulative_school_related_cases  cumulative_school_related_student_cases  \
# 48                             3710                                     2147
# 49                             3803                                     2209
# 50                             3870                                     2267
# 51                             4170                                     2516
# 52                             4269                                     2609
#
#     cumulative_school_related_staff_cases  \
# 48                                    476
# 49                                    507
# 50                                    516
# 51                                    568
# 52                                    573
#
#     cumulative_school_related_unspecified_cases
# 48                                       1087.0
# 49                                       1087.0
# 50                                       1087.0
# 51                                       1086.0
# 52                                       1087.0

# %% [markdown]
# ### Save the modified dataframe to a new csv file

# %%
df.to_csv("C:/Users/P/data_analyst_role/Ontario_Schools_COVID-19_Analysis_2020/ontario_schools_covid19_analysis/ont_school_covid19_101.csv", 
          index = False, header = True)
