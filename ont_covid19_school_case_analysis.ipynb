# %% [markdown]
# # ONTARIO SCHOOLS WITH COVID-19 CASES ANALYSIS
# ## Peter Stangolis
#
# #### [Data URL:](https://data.ontario.ca/dataset/b1fef838-8784-4338-8ef9-ae7cfd405b41/resource/7fbdbb48-d074-45d9-93cb-f7de58950418/download/schoolcovidsummary.csv)

# %% [markdown]
# ### Import the required libraries for the analysis

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from matplotlib.pyplot import figure

from pylab import rcParams
#rcParams['figure.figsize'] = 18, 6

import datetime
import seaborn as sns

# %%
# Graph Style Settings:

plt.figure(figsize=(7, 4))

plt.style.use(['default', 'ggplot'])

# %matplotlib inline

# %% [markdown]
# ### Import the data set into a dataframe

# %%
url = 'https://data.ontario.ca/dataset/b1fef838-8784-4338-8ef9-ae7cfd405b41/resource/7fbdbb48-d074-45d9-93cb-f7de58950418/download/schoolcovidsummary.csv'

df = pd.read_csv(url)

# View the last 5 rows of the data set
df.tail()
# Out:
#    collected_date reported_date  current_schools_w_cases  \
# 45     2020-11-13    2020-11-16                      683
# 46     2020-11-16    2020-11-17                      670
# 47     2020-11-17    2020-11-18                      670
# 48     2020-11-18    2020-11-19                      680
# 49     2020-11-19    2020-11-20                      681
#
#     current_schools_closed  current_total_number_schools  \
# 45                       1                          4828
# 46                       1                          4828
# 47                       3                          4828
# 48                       3                          4828
# 49                       3                          4828
#
#     new_total_school_related_cases  new_school_related_student_cases  \
# 45                             106                                63
# 46                             133                                73
# 47                             109                                92
# 48                              91                                75
# 49                              87                                60
#
#     new_school_related_staff_cases  new_school_related_unspecified_cases  \
# 45                              14                                  29.0
# 46                              23                                  37.0
# 47                              17                                   0.0
# 48                              16                                   0.0
# 49                              27                                   0.0
#
#     recent_total_school_related_cases  ...  \
# 45                             1143.0  ...
# 46                             1126.0  ...
# 47                             1121.0  ...
# 48                             1143.0  ...
# 49                             1150.0  ...
#
#     recent_school_related_unspecified_cases  past_total_school_related_cases  \
# 45                                    354.0                           2244.0
# 46                                    352.0                           2392.0
# 47                                    324.0                           2505.0
# 48                                    299.0                           2567.0
# 49                                    271.0                           2653.0
#
#     past_school_related_student_cases  past_school_related_staff_cases  \
# 45                             1249.0                            298.0
# 46                             1342.0                            314.0
# 47                             1419.0                            322.0
# 48                             1451.0                            328.0
# 49                             1503.0                            334.0
#
#     past_school_related_unspecified_cases  cumulative_school_related_cases  \
# 45                                  697.0                             3387
# 46                                  736.0                             3518
# 47                                  764.0                             3626
# 48                                  788.0                             3710
# 49                                  816.0                             3803
#
#     cumulative_school_related_student_cases  \
# 45                                     1913
# 46                                     1985
# 47                                     2077
# 48                                     2147
# 49                                     2209
#
#     cumulative_school_related_staff_cases  \
# 45                                    423
# 46                                    445
# 47                                    461
# 48                                    476
# 49                                    507
#
#     cumulative_school_related_unspecified_cases  Unnamed: 21
# 45                                       1051.0          NaN
# 46                                       1088.0          NaN
# 47                                       1088.0          NaN
# 48                                       1087.0          NaN
# 49                                       1087.0          NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Initial Exploratory Data Analysis of the data set

# %%
# retrieve information concerning the data in columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 22 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   collected_date                               50 non-null     object
#  1   reported_date                                50 non-null     object
#  2   current_schools_w_cases                      50 non-null     int64
#  3   current_schools_closed                       50 non-null     int64
#  4   current_total_number_schools                 50 non-null     int64
#  5   new_total_school_related_cases               50 non-null     int64
#  6   new_school_related_student_cases             50 non-null     int64
#  7   new_school_related_staff_cases               50 non-null     int64
#  8   new_school_related_unspecified_cases         48 non-null     float64
#  9   recent_total_school_related_cases            36 non-null     float64
#  10  recent_school_related_student_cases          36 non-null     float64
#  11  recent_school_related_staff_cases            36 non-null     float64
#  12  recent_school_related_unspecified_cases      36 non-null     float64
#  13  past_total_school_related_cases              36 non-null     float64
#  14  past_school_related_student_cases            36 non-null     float64
#  15  past_school_related_staff_cases              36 non-null     float64
#  16  past_school_related_unspecified_cases        36 non-null     float64
#  17  cumulative_school_related_cases              50 non-null     int64
#  18  cumulative_school_related_student_cases      50 non-null     int64
#  19  cumulative_school_related_staff_cases        50 non-null     int64
#  20  cumulative_school_related_unspecified_cases  48 non-null     float64
#  21  Unnamed: 21                                  0 non-null      float64
# dtypes: float64(11), int64(9), object(2)
# memory usage: 8.7+ KB

# %% [markdown]
# ### Change the datatype of the 'reported_date' column to datetime from object

# %%
df['reported_date'] = pd.to_datetime(df['reported_date'])

# %%
df['reported_date'].head()
# Out:
# 0   2020-09-11
# 1   2020-09-14
# 2   2020-09-15
# 3   2020-09-16
# 4   2020-09-17
# Name: reported_date, dtype: datetime64[ns]

# %%
df.describe()
# Out:
#        current_schools_w_cases  current_schools_closed  \
# count                50.000000               50.000000
# mean                415.880000                1.960000
# std                 214.336341                1.538088
# min                  13.000000                0.000000
# 25%                 257.250000                1.000000
# 50%                 484.000000                2.000000
# 75%                 581.000000                3.000000
# max                 683.000000                5.000000
#
#        current_total_number_schools  new_total_school_related_cases  \
# count                          50.0                       50.000000
# mean                         4828.0                       77.200000
# std                             0.0                       43.238305
# min                          4828.0                        0.000000
# 25%                          4828.0                       51.250000
# 50%                          4828.0                       74.000000
# 75%                          4828.0                      105.250000
# max                          4828.0                      198.000000
#
#        new_school_related_student_cases  new_school_related_staff_cases  \
# count                         50.000000                       50.000000
# mean                          44.980000                       10.200000
# std                           26.881061                        6.543419
# min                            0.000000                        0.000000
# 25%                           29.000000                        5.000000
# 50%                           41.000000                        9.000000
# 75%                           59.000000                       13.750000
# max                          116.000000                       27.000000
#
#        new_school_related_unspecified_cases  \
# count                             48.000000
# mean                              22.937500
# std                               15.213944
# min                                0.000000
# 25%                               12.000000
# 50%                               22.500000
# 75%                               31.250000
# max                               65.000000
#
#        recent_total_school_related_cases  recent_school_related_student_cases  \
# count                          36.000000                            36.000000
# mean                          832.305556                           476.111111
# std                           216.242565                           128.196674
# min                           386.000000                           212.000000
# 25%                           679.750000                           396.750000
# 50%                           889.500000                           480.500000
# 75%                           936.500000                           532.000000
# max                          1150.000000                           706.000000
#
#        recent_school_related_staff_cases  \
# count                          36.000000
# mean                           99.388889
# std                            24.108419
# min                            59.000000
# 25%                            84.750000
# 50%                            99.000000
# 75%                           107.750000
# max                           173.000000
#
#        recent_school_related_unspecified_cases  \
# count                                36.000000
# mean                                256.750000
# std                                  77.833293
# min                                 114.000000
# 25%                                 184.500000
# 50%                                 290.500000
# 75%                                 318.750000
# max                                 354.000000
#
#        past_total_school_related_cases  past_school_related_student_cases  \
# count                        36.000000                          36.000000
# mean                       1162.805556                         646.805556
# std                         825.850205                         470.260768
# min                          61.000000                          21.000000
# 25%                         443.000000                         228.000000
# 50%                        1020.500000                         582.000000
# 75%                        1833.000000                        1027.250000
# max                        2653.000000                        1503.000000
#
#        past_school_related_staff_cases  past_school_related_unspecified_cases  \
# count                        36.000000                              36.000000
# mean                        171.027778                             344.944444
# std                         102.336277                             254.324084
# min                          23.000000                              17.000000
# 25%                          82.000000                             133.000000
# 50%                         162.500000                             276.000000
# 75%                         256.750000                             549.000000
# max                         334.000000                             816.000000
#
#        cumulative_school_related_cases  \
# count                        50.000000
# mean                       1476.680000
# std                        1211.690663
# min                          13.000000
# 25%                         315.750000
# 50%                        1276.000000
# 75%                        2447.000000
# max                        3803.000000
#
#        cumulative_school_related_student_cases  \
# count                                 50.00000
# mean                                 827.46000
# std                                  694.32502
# min                                    4.00000
# 25%                                  170.00000
# 50%                                  713.00000
# 75%                                 1378.75000
# max                                 2209.00000
#
#        cumulative_school_related_staff_cases  \
# count                              50.000000
# mean                              203.220000
# std                               148.194755
# min                                 9.000000
# 25%                                50.500000
# 50%                               198.500000
# 75%                               311.250000
# max                               507.000000
#
#        cumulative_school_related_unspecified_cases  Unnamed: 21
# count                                    48.000000          0.0
# mean                                    464.604167          NaN
# std                                     366.279264          NaN
# min                                       6.000000          NaN
# 25%                                     125.500000          NaN
# 50%                                     384.000000          NaN
# 75%                                     770.000000          NaN
# max                                    1088.000000          NaN

# %% [markdown]
# ### Missing Value Analysis

# %%
df.isnull().sum()
# Out:
# collected_date                                  0
# reported_date                                   0
# current_schools_w_cases                         0
# current_schools_closed                          0
# current_total_number_schools                    0
# new_total_school_related_cases                  0
# new_school_related_student_cases                0
# new_school_related_staff_cases                  0
# new_school_related_unspecified_cases            2
# recent_total_school_related_cases              14
# recent_school_related_student_cases            14
# recent_school_related_staff_cases              14
# recent_school_related_unspecified_cases        14
# past_total_school_related_cases                14
# past_school_related_student_cases              14
# past_school_related_staff_cases                14
# past_school_related_unspecified_cases          14
# cumulative_school_related_cases                 0
# cumulative_school_related_student_cases         0
# cumulative_school_related_staff_cases           0
# cumulative_school_related_unspecified_cases     2
# Unnamed: 21                                    50
# dtype: int64

# %% [markdown]
# ### Drop the columns not required for the analysis
#
#
# * collected_date
# * recent_total_school_related_cases
# * recent_school_related_student_cases
# * recent_school_related_staff_cases
# * recent_school_related_unspecified_cases
# * past_total_school_related_cases
# * past_school_related_student_cases
# * past_school_related_staff_cases
# * past_school_related_unspecified_cases
# * Unnamed: 21

# %%
df = df.iloc[:,  [1,2,3,4,5,6,7,8,9, 17, 18, 19, 20]]

# %%
df.tail()
# Out:
#    reported_date  current_schools_w_cases  current_schools_closed  \
# 45    2020-11-16                      683                       1
# 46    2020-11-17                      670                       1
# 47    2020-11-18                      670                       3
# 48    2020-11-19                      680                       3
# 49    2020-11-20                      681                       3
#
#     current_total_number_schools  new_total_school_related_cases  \
# 45                          4828                             106
# 46                          4828                             133
# 47                          4828                             109
# 48                          4828                              91
# 49                          4828                              87
#
#     new_school_related_student_cases  new_school_related_staff_cases  \
# 45                                63                              14
# 46                                73                              23
# 47                                92                              17
# 48                                75                              16
# 49                                60                              27
#
#     new_school_related_unspecified_cases  recent_total_school_related_cases  \
# 45                                  29.0                             1143.0
# 46                                  37.0                             1126.0
# 47                                   0.0                             1121.0
# 48                                   0.0                             1143.0
# 49                                   0.0                             1150.0
#
#     cumulative_school_related_cases  cumulative_school_related_student_cases  \
# 45                             3387                                     1913
# 46                             3518                                     1985
# 47                             3626                                     2077
# 48                             3710                                     2147
# 49                             3803                                     2209
#
#     cumulative_school_related_staff_cases  \
# 45                                    423
# 46                                    445
# 47                                    461
# 48                                    476
# 49                                    507
#
#     cumulative_school_related_unspecified_cases
# 45                                       1051.0
# 46                                       1088.0
# 47                                       1088.0
# 48                                       1087.0
# 49                                       1087.0

# %% [markdown]
# ### Save the modified dataframe to a new csv file

# %%
df.to_csv("C:/Users/P/data_analyst_role/Ontario_Schools_COVID-19_Analysis_2020/ontario_schools_covid19_analysis/ont_school_covid19_101.csv", 
          index = False, header = True)
