# %% [markdown]
# # ONTARIO SCHOOLS WITH COVID-19 CASES ANALYSIS
# ## Initial Cleaning of Data set for further analysis
#
# ### Peter Stangolis
#
# #### [Data URL:](https://data.ontario.ca/dataset/b1fef838-8784-4338-8ef9-ae7cfd405b41/resource/7fbdbb48-d074-45d9-93cb-f7de58950418/download/schoolcovidsummary.csv)

# %% [markdown]
# ### Import the required libraries for the analysis

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from matplotlib.pyplot import figure

from pylab import rcParams
#rcParams['figure.figsize'] = 18, 6

import datetime
import seaborn as sns

# %%
# Graph Style Settings:

plt.figure(figsize=(7, 4))

plt.style.use(['default', 'tableau-colorblind10'])

# %matplotlib inline

# %%
for s in plt.style.available:
    print(s)
# Out:
# Solarize_Light2
# _classic_test_patch
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn
# seaborn-bright
# seaborn-colorblind
# seaborn-dark
# seaborn-dark-palette
# seaborn-darkgrid
# seaborn-deep
# seaborn-muted
# seaborn-notebook
# seaborn-paper
# seaborn-pastel
# seaborn-poster
# seaborn-talk
# seaborn-ticks
# seaborn-white
# seaborn-whitegrid
# tableau-colorblind10

# %% [markdown]
# ### Import the data set into a dataframe

# %%
url = 'https://data.ontario.ca/dataset/b1fef838-8784-4338-8ef9-ae7cfd405b41/resource/7fbdbb48-d074-45d9-93cb-f7de58950418/download/schoolcovidsummary.csv'

df = pd.read_csv(url)

# View the last 5 rows of the data set
df.tail()
# Out:
#    collected_date reported_date  current_schools_w_cases  \
# 46     2020-11-16    2020-11-17                      670
# 47     2020-11-17    2020-11-18                      670
# 48     2020-11-18    2020-11-19                      680
# 49     2020-11-19    2020-11-20                      681
# 50     2020-11-20    2020-11-23                      676
#
#     current_schools_closed  current_total_number_schools  \
# 46                       1                          4828
# 47                       3                          4828
# 48                       3                          4828
# 49                       3                          4828
# 50                       3                          4828
#
#     new_total_school_related_cases  new_school_related_student_cases  \
# 46                             133                                73
# 47                             109                                92
# 48                              91                                75
# 49                              87                                60
# 50                              60                                51
#
#     new_school_related_staff_cases  new_school_related_unspecified_cases  \
# 46                              23                                  37.0
# 47                              17                                   0.0
# 48                              16                                   0.0
# 49                              27                                   0.0
# 50                               9                                   0.0
#
#     recent_total_school_related_cases  ...  \
# 46                             1126.0  ...
# 47                             1121.0  ...
# 48                             1143.0  ...
# 49                             1150.0  ...
# 50                             1133.0  ...
#
#     recent_school_related_unspecified_cases  past_total_school_related_cases  \
# 46                                    352.0                           2392.0
# 47                                    324.0                           2505.0
# 48                                    299.0                           2567.0
# 49                                    271.0                           2653.0
# 50                                    244.0                           2737.0
#
#     past_school_related_student_cases  past_school_related_staff_cases  \
# 46                             1342.0                            314.0
# 47                             1419.0                            322.0
# 48                             1451.0                            328.0
# 49                             1503.0                            334.0
# 50                             1549.0                            345.0
#
#     past_school_related_unspecified_cases  cumulative_school_related_cases  \
# 46                                  736.0                             3518
# 47                                  764.0                             3626
# 48                                  788.0                             3710
# 49                                  816.0                             3803
# 50                                  843.0                             3870
#
#     cumulative_school_related_student_cases  \
# 46                                     1985
# 47                                     2077
# 48                                     2147
# 49                                     2209
# 50                                     2267
#
#     cumulative_school_related_staff_cases  \
# 46                                    445
# 47                                    461
# 48                                    476
# 49                                    507
# 50                                    516
#
#     cumulative_school_related_unspecified_cases  Unnamed: 21
# 46                                       1088.0          NaN
# 47                                       1088.0          NaN
# 48                                       1087.0          NaN
# 49                                       1087.0          NaN
# 50                                       1087.0          NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Initial Exploratory Data Analysis of the data set

# %%
# retrieve information concerning the data in columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 22 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   collected_date                               51 non-null     object
#  1   reported_date                                51 non-null     object
#  2   current_schools_w_cases                      51 non-null     int64
#  3   current_schools_closed                       51 non-null     int64
#  4   current_total_number_schools                 51 non-null     int64
#  5   new_total_school_related_cases               51 non-null     int64
#  6   new_school_related_student_cases             51 non-null     int64
#  7   new_school_related_staff_cases               51 non-null     int64
#  8   new_school_related_unspecified_cases         49 non-null     float64
#  9   recent_total_school_related_cases            37 non-null     float64
#  10  recent_school_related_student_cases          37 non-null     float64
#  11  recent_school_related_staff_cases            37 non-null     float64
#  12  recent_school_related_unspecified_cases      37 non-null     float64
#  13  past_total_school_related_cases              37 non-null     float64
#  14  past_school_related_student_cases            37 non-null     float64
#  15  past_school_related_staff_cases              37 non-null     float64
#  16  past_school_related_unspecified_cases        37 non-null     float64
#  17  cumulative_school_related_cases              51 non-null     int64
#  18  cumulative_school_related_student_cases      51 non-null     int64
#  19  cumulative_school_related_staff_cases        51 non-null     int64
#  20  cumulative_school_related_unspecified_cases  49 non-null     float64
#  21  Unnamed: 21                                  0 non-null      float64
# dtypes: float64(11), int64(9), object(2)
# memory usage: 8.9+ KB

# %% [markdown]
# ### Change the datatype of the 'reported_date' column to datetime from object

# %%
df['reported_date'] = pd.to_datetime(df['reported_date'])

# %%
df['reported_date'].head()
# Out:
# 0   2020-09-11
# 1   2020-09-14
# 2   2020-09-15
# 3   2020-09-16
# 4   2020-09-17
# Name: reported_date, dtype: datetime64[ns]

# %%
df.describe()
# Out:
#        current_schools_w_cases  current_schools_closed  \
# count                51.000000               51.000000
# mean                420.980392                1.980392
# std                 215.285809                1.529578
# min                  13.000000                0.000000
# 25%                 265.500000                1.000000
# 50%                 485.000000                2.000000
# 75%                 581.500000                3.000000
# max                 683.000000                5.000000
#
#        current_total_number_schools  new_total_school_related_cases  \
# count                          51.0                       51.000000
# mean                         4828.0                       76.862745
# std                             0.0                       42.871445
# min                          4828.0                        0.000000
# 25%                          4828.0                       51.500000
# 50%                          4828.0                       74.000000
# 75%                          4828.0                      104.500000
# max                          4828.0                      198.000000
#
#        new_school_related_student_cases  new_school_related_staff_cases  \
# count                         51.000000                       51.000000
# mean                          45.098039                       10.176471
# std                           26.624241                        6.479833
# min                            0.000000                        0.000000
# 25%                           29.000000                        5.000000
# 50%                           41.000000                        9.000000
# 75%                           58.000000                       13.500000
# max                          116.000000                       27.000000
#
#        new_school_related_unspecified_cases  \
# count                             49.000000
# mean                              22.469388
# std                               15.407117
# min                                0.000000
# 25%                               12.000000
# 50%                               22.000000
# 75%                               31.000000
# max                               65.000000
#
#        recent_total_school_related_cases  recent_school_related_student_cases  \
# count                          37.000000                            37.000000
# mean                          840.432432                           482.648649
# std                           218.873573                           132.511261
# min                           386.000000                           212.000000
# 25%                           686.000000                           399.000000
# 50%                           890.000000                           481.000000
# 75%                           938.000000                           547.000000
# max                          1150.000000                           718.000000
#
#        recent_school_related_staff_cases  \
# count                          37.000000
# mean                          101.324324
# std                            26.526773
# min                            59.000000
# 25%                            86.000000
# 50%                            99.000000
# 75%                           110.000000
# max                           173.000000
#
#        recent_school_related_unspecified_cases  \
# count                                37.000000
# mean                                256.405405
# std                                  76.773281
# min                                 114.000000
# 25%                                 188.000000
# 50%                                 290.000000
# 75%                                 317.000000
# max                                 354.000000
#
#        past_total_school_related_cases  past_school_related_student_cases  \
# count                        37.000000                          37.000000
# mean                       1205.351351                         671.189189
# std                         854.434713                         486.827533
# min                          61.000000                          21.000000
# 25%                         459.000000                         236.000000
# 50%                        1063.000000                         604.000000
# 75%                        1929.000000                        1079.000000
# max                        2737.000000                        1549.000000
#
#        past_school_related_staff_cases  past_school_related_unspecified_cases  \
# count                        37.000000                              37.000000
# mean                        175.729730                             358.405405
# std                         104.879997                             263.796055
# min                          23.000000                              17.000000
# 25%                          85.000000                             138.000000
# 50%                         167.000000                             292.000000
# 75%                         265.000000                             585.000000
# max                         345.000000                             843.000000
#
#        cumulative_school_related_cases  \
# count                        51.000000
# mean                       1523.607843
# std                        1245.449205
# min                          13.000000
# 25%                         324.500000
# 50%                        1310.000000
# 75%                        2509.500000
# max                        3870.000000
#
#        cumulative_school_related_student_cases  \
# count                                51.000000
# mean                                855.686275
# std                                 716.294869
# min                                   4.000000
# 25%                                 176.000000
# 50%                                 736.000000
# 75%                                1417.000000
# max                                2267.000000
#
#        cumulative_school_related_staff_cases  \
# count                              51.000000
# mean                              209.352941
# std                               153.103602
# min                                 9.000000
# 25%                                51.000000
# 50%                               202.000000
# 75%                               316.500000
# max                               516.000000
#
#        cumulative_school_related_unspecified_cases  Unnamed: 21
# count                                    49.000000          0.0
# mean                                    477.306122          NaN
# std                                     373.190479          NaN
# min                                       6.000000          NaN
# 25%                                     132.000000          NaN
# 50%                                     396.000000          NaN
# 75%                                     788.000000          NaN
# max                                    1088.000000          NaN

# %% [markdown]
# ### Missing Value Analysis

# %%
df.isnull().sum()
# Out:
# collected_date                                  0
# reported_date                                   0
# current_schools_w_cases                         0
# current_schools_closed                          0
# current_total_number_schools                    0
# new_total_school_related_cases                  0
# new_school_related_student_cases                0
# new_school_related_staff_cases                  0
# new_school_related_unspecified_cases            2
# recent_total_school_related_cases              14
# recent_school_related_student_cases            14
# recent_school_related_staff_cases              14
# recent_school_related_unspecified_cases        14
# past_total_school_related_cases                14
# past_school_related_student_cases              14
# past_school_related_staff_cases                14
# past_school_related_unspecified_cases          14
# cumulative_school_related_cases                 0
# cumulative_school_related_student_cases         0
# cumulative_school_related_staff_cases           0
# cumulative_school_related_unspecified_cases     2
# Unnamed: 21                                    51
# dtype: int64

# %% [markdown]
# ### Drop the columns not required for the analysis
#
#
# * collected_date
# * recent_total_school_related_cases
# * recent_school_related_student_cases
# * recent_school_related_staff_cases
# * recent_school_related_unspecified_cases
# * past_total_school_related_cases
# * past_school_related_student_cases
# * past_school_related_staff_cases
# * past_school_related_unspecified_cases
# * Unnamed: 21

# %%
df = df.iloc[:,  [1,2,3,4,5,6,7,8,9, 17, 18, 19, 20]]

# %%
df.tail()
# Out:
#    reported_date  current_schools_w_cases  current_schools_closed  \
# 46    2020-11-17                      670                       1
# 47    2020-11-18                      670                       3
# 48    2020-11-19                      680                       3
# 49    2020-11-20                      681                       3
# 50    2020-11-23                      676                       3
#
#     current_total_number_schools  new_total_school_related_cases  \
# 46                          4828                             133
# 47                          4828                             109
# 48                          4828                              91
# 49                          4828                              87
# 50                          4828                              60
#
#     new_school_related_student_cases  new_school_related_staff_cases  \
# 46                                73                              23
# 47                                92                              17
# 48                                75                              16
# 49                                60                              27
# 50                                51                               9
#
#     new_school_related_unspecified_cases  recent_total_school_related_cases  \
# 46                                  37.0                             1126.0
# 47                                   0.0                             1121.0
# 48                                   0.0                             1143.0
# 49                                   0.0                             1150.0
# 50                                   0.0                             1133.0
#
#     cumulative_school_related_cases  cumulative_school_related_student_cases  \
# 46                             3518                                     1985
# 47                             3626                                     2077
# 48                             3710                                     2147
# 49                             3803                                     2209
# 50                             3870                                     2267
#
#     cumulative_school_related_staff_cases  \
# 46                                    445
# 47                                    461
# 48                                    476
# 49                                    507
# 50                                    516
#
#     cumulative_school_related_unspecified_cases
# 46                                       1088.0
# 47                                       1088.0
# 48                                       1087.0
# 49                                       1087.0
# 50                                       1087.0

# %% [markdown]
# ### Save the modified dataframe to a new csv file

# %%
df.to_csv("C:/Users/P/data_analyst_role/Ontario_Schools_COVID-19_Analysis_2020/ontario_schools_covid19_analysis/ont_school_covid19_101.csv", 
          index = False, header = True)
